# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Extracting Dataset

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('C:\workspace\Credit-Risk-Modeling\dataset\kaggle_pd_estimation\credit_risk_dataset.csv').drop_duplicates()

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
num_features=['person_age', 'person_income','person_emp_length', 'loan_amnt',
       'loan_int_rate','loan_percent_income','cb_person_cred_hist_length']
cat_features=['person_home_ownership','loan_intent', 'loan_grade','cb_person_default_on_file']
target='loan_status'

len(num_features)+len(cat_features)
# Out:
# 11

# %% [markdown]
# # Overview of missing data

# %%
df.isna().any()
# Out:
# person_age                    False
# person_income                 False
# person_home_ownership         False
# person_emp_length              True
# loan_intent                   False
# loan_grade                    False
# loan_amnt                     False
# loan_int_rate                  True
# loan_status                   False
# loan_percent_income           False
# cb_person_default_on_file     False
# cb_person_cred_hist_length    False
# dtype: bool

# %%
df.loc[df.isna().any(axis=1)==True]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 39             23          71500                  RENT                3.0
# 50             24          78000                  RENT                4.0
# 57             23         277000                   OWN                3.0
# 59             24          12000                   OWN                2.0
# 62             26         263000              MORTGAGE                0.0
# ...           ...            ...                   ...                ...
# 32547          53           4888                   OWN                0.0
# 32552          65          45900                  RENT                2.0
# 32553          54          20000                  RENT                2.0
# 32569          51          60000              MORTGAGE                1.0
# 32570          58          72000                  RENT                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 39     DEBTCONSOLIDATION          D      30000            NaN            1
# 50     DEBTCONSOLIDATION          D      30000            NaN            1
# 57              PERSONAL          A      35000            NaN            0
# 59               VENTURE          E       1750            NaN            0
# 62             EDUCATION          B      10000            NaN            1
# ...                  ...        ...        ...            ...          ...
# 32547            VENTURE          C       1400            NaN            1
# 32552          EDUCATION          C      10000            NaN            0
# 32553            MEDICAL          C       5000            NaN            0
# 32569           PERSONAL          A       7500            NaN            0
# 32570    HOMEIMPROVEMENT          B       4500            NaN            0
#
#        loan_percent_income cb_person_default_on_file  \
# 39                    0.42                         N
# 50                    0.38                         Y
# 57                    0.13                         N
# 59                    0.15                         Y
# 62                    0.04                         N
# ...                    ...                       ...
# 32547                 0.29                         Y
# 32552                 0.22                         Y
# 32553                 0.25                         N
# 32569                 0.13                         N
# 32570                 0.06                         N
#
#        cb_person_cred_hist_length
# 39                              4
# 50                              4
# 57                              4
# 59                              3
# 62                              4
# ...                           ...
# 32547                          28
# 32552                          19
# 32553                          28
# 32569                          23
# 32570                          23
#
# [3915 rows x 12 columns]

# %%
df[df['loan_int_rate'].isna()==True]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 39             23          71500                  RENT                3.0
# 50             24          78000                  RENT                4.0
# 57             23         277000                   OWN                3.0
# 59             24          12000                   OWN                2.0
# 62             26         263000              MORTGAGE                0.0
# ...           ...            ...                   ...                ...
# 32547          53           4888                   OWN                0.0
# 32552          65          45900                  RENT                2.0
# 32553          54          20000                  RENT                2.0
# 32569          51          60000              MORTGAGE                1.0
# 32570          58          72000                  RENT                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 39     DEBTCONSOLIDATION          D      30000            NaN            1
# 50     DEBTCONSOLIDATION          D      30000            NaN            1
# 57              PERSONAL          A      35000            NaN            0
# 59               VENTURE          E       1750            NaN            0
# 62             EDUCATION          B      10000            NaN            1
# ...                  ...        ...        ...            ...          ...
# 32547            VENTURE          C       1400            NaN            1
# 32552          EDUCATION          C      10000            NaN            0
# 32553            MEDICAL          C       5000            NaN            0
# 32569           PERSONAL          A       7500            NaN            0
# 32570    HOMEIMPROVEMENT          B       4500            NaN            0
#
#        loan_percent_income cb_person_default_on_file  \
# 39                    0.42                         N
# 50                    0.38                         Y
# 57                    0.13                         N
# 59                    0.15                         Y
# 62                    0.04                         N
# ...                    ...                       ...
# 32547                 0.29                         Y
# 32552                 0.22                         Y
# 32553                 0.25                         N
# 32569                 0.13                         N
# 32570                 0.06                         N
#
#        cb_person_cred_hist_length
# 39                              4
# 50                              4
# 57                              4
# 59                              3
# 62                              4
# ...                           ...
# 32547                          28
# 32552                          19
# 32553                          28
# 32569                          23
# 32570                          23
#
# [3095 rows x 12 columns]

# %%
df['loan_int_rate'].isna().value_counts()
# Out:
# loan_int_rate
# False    29321
# True      3095
# Name: count, dtype: int64

# %%
df[df['person_emp_length'].isna()==True]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 105            22          12600              MORTGAGE                NaN
# 222            24         185000              MORTGAGE                NaN
# 379            24          16800              MORTGAGE                NaN
# 407            25          52000                  RENT                NaN
# 408            22          17352              MORTGAGE                NaN
# ...           ...            ...                   ...                ...
# 32285          38          12000                   OWN                NaN
# 32328          51          18408                  RENT                NaN
# 32360          70          39996                  RENT                NaN
# 32453          56          32400                  RENT                NaN
# 32471          53          54000                  RENT                NaN
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 105             PERSONAL          A       2000           5.42            1
# 222            EDUCATION          B      35000          12.42            0
# 379    DEBTCONSOLIDATION          A       3900            NaN            1
# 407             PERSONAL          B      24000          10.74            1
# 408            EDUCATION          C       2250          15.27            0
# ...                  ...        ...        ...            ...          ...
# 32285          EDUCATION          A       4800           7.29            1
# 32328           PERSONAL          C       1000          14.65            1
# 32360            MEDICAL          C       3600          15.23            0
# 32453            MEDICAL          A       8575           7.51            0
# 32471            MEDICAL          D      10000          14.59            1
#
#        loan_percent_income cb_person_default_on_file  \
# 105                   0.16                         N
# 222                   0.19                         N
# 379                   0.23                         N
# 407                   0.46                         N
# 408                   0.13                         Y
# ...                    ...                       ...
# 32285                 0.40                         N
# 32328                 0.05                         Y
# 32360                 0.09                         Y
# 32453                 0.26                         N
# 32471                 0.19                         Y
#
#        cb_person_cred_hist_length
# 105                             4
# 222                             2
# 379                             3
# 407                             2
# 408                             3
# ...                           ...
# 32285                          12
# 32328                          20
# 32360                          19
# 32453                          18
# 32471                          27
#
# [887 rows x 12 columns]

# %%
df['person_emp_length'].isna().value_counts()
# Out:
# person_emp_length
# False    31529
# True       887
# Name: count, dtype: int64

# %% [markdown]
# ## Investigating the relationshib between `employment length` and other features
#
# - We have used regression tree.
#
# - employment length is target.
#
# - Rest of the features are the features of the regression tree.

# %%
X=pd.get_dummies(df[num_features+cat_features].dropna())
y=df.dropna()['loan_status']

# %%
from sklearn.tree import DecisionTreeRegressor 
model=DecisionTreeRegressor().fit(X,y)

# %%
feature_score=pd.concat([pd.Series(model.feature_names_in_),pd.Series(model.feature_importances_)],axis=1)
feature_score.columns=['features','score']
feature_score.sort_values('score',ascending=False,inplace=True)
feature_score.index=range(len(feature_score))
feature_score.head(10)
# Out:
#                         features     score
# 0            loan_percent_income  0.231482
# 1                  loan_int_rate  0.178024
# 2     person_home_ownership_RENT  0.129202
# 3                  person_income  0.129083
# 4              person_emp_length  0.053805
# 5            loan_intent_MEDICAL  0.040424
# 6                      loan_amnt  0.040142
# 7                     person_age  0.038511
# 8  loan_intent_DEBTCONSOLIDATION  0.034387
# 9     cb_person_cred_hist_length  0.026807

# %%
model.feature_names_in_
# Out:
# array(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income',
#        'cb_person_cred_hist_length', 'person_home_ownership_MORTGAGE',
#        'person_home_ownership_OTHER', 'person_home_ownership_OWN',
#        'person_home_ownership_RENT', 'loan_intent_DEBTCONSOLIDATION',
#        'loan_intent_EDUCATION', 'loan_intent_HOMEIMPROVEMENT',
#        'loan_intent_MEDICAL', 'loan_intent_PERSONAL',
#        'loan_intent_VENTURE', 'loan_grade_A', 'loan_grade_B',
#        'loan_grade_C', 'loan_grade_D', 'loan_grade_E', 'loan_grade_F',
#        'loan_grade_G', 'cb_person_default_on_file_N',
#        'cb_person_default_on_file_Y'], dtype=object)

# %% [markdown]
# # Overview of portion of defult loans vs good ones

# %%
df['loan_status'].value_counts(normalize=True)
# Out:
# loan_status
# 0    0.781312
# 1    0.218688
# Name: proportion, dtype: float64

# %% [markdown]
# # Investigating Categorical and Numerical features

# %%
df['cb_person_default_on_file'].value_counts(normalize=True)
# Out:
# cb_person_default_on_file
# N    0.823235
# Y    0.176765
# Name: proportion, dtype: float64

# %%
cat_features=['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file']
num_features=['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
       'loan_int_rate','loan_percent_income','cb_person_cred_hist_length']

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
df[num_features]
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 32576          57          53000                1.0       5800          13.16
# 32577          54         120000                4.0      17625           7.49
# 32578          65          76000                3.0      35000          10.99
# 32579          56         150000                5.0      15000          11.48
# 32580          66          42000                2.0       6475           9.99
#
#        loan_percent_income  cb_person_cred_hist_length
# 0                     0.59                           3
# 1                     0.10                           2
# 2                     0.57                           3
# 3                     0.53                           2
# 4                     0.55                           4
# ...                    ...                         ...
# 32576                 0.11                          30
# 32577                 0.15                          19
# 32578                 0.46                          28
# 32579                 0.10                          26
# 32580                 0.15                          30
#
# [32416 rows x 7 columns]

# %%
df[cat_features]
# Out:
#       person_home_ownership      loan_intent loan_grade  \
# 0                      RENT         PERSONAL          D
# 1                       OWN        EDUCATION          B
# 2                  MORTGAGE          MEDICAL          C
# 3                      RENT          MEDICAL          C
# 4                      RENT          MEDICAL          C
# ...                     ...              ...        ...
# 32576              MORTGAGE         PERSONAL          C
# 32577              MORTGAGE         PERSONAL          A
# 32578                  RENT  HOMEIMPROVEMENT          B
# 32579              MORTGAGE         PERSONAL          B
# 32580                  RENT          MEDICAL          B
#
#       cb_person_default_on_file
# 0                             Y
# 1                             N
# 2                             N
# 3                             N
# 4                             Y
# ...                         ...
# 32576                         N
# 32577                         N
# 32578                         N
# 32579                         N
# 32580                         N
#
# [32416 rows x 4 columns]

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        16378
# MORTGAGE    13369
# OWN          2563
# OTHER         106
# Name: count, dtype: int64

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            6411
# MEDICAL              6042
# VENTURE              5682
# PERSONAL             5498
# DEBTCONSOLIDATION    5189
# HOMEIMPROVEMENT      3594
# Name: count, dtype: int64

# %%
df['loan_grade'].value_counts()
# Out:
# loan_grade
# A    10703
# B    10387
# C     6438
# D     3620
# E      963
# F      241
# G       64
# Name: count, dtype: int64

# %%
target='loan_status'
df[target]=df[target].astype('category')

# %%
from sklearn.preprocessing import OneHotEncoder,PowerTransformer,LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df[target].astype('category').value_counts()
# Out:
# loan_status
# 0    25327
# 1     7089
# Name: count, dtype: int64

# %%
df['person_emp_length'].hist(bins=20)
# Out:
# <Axes: >

# %%
df[df['person_emp_length']>40]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 210            21         192000              MORTGAGE              123.0
# 32355          78          48000                  RENT               41.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate loan_status  \
# 0        PERSONAL          D      35000          16.02           1
# 210       VENTURE          A      20000           6.54           0
# 32355     MEDICAL          A       3000           7.51           0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 210                   0.10                         N
# 32355                 0.06                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 210                             4
# 32355                          25

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            6411
# MEDICAL              6042
# VENTURE              5682
# PERSONAL             5498
# DEBTCONSOLIDATION    5189
# HOMEIMPROVEMENT      3594
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
temp_df=pd.DataFrame(df[['loan_intent','loan_status']].value_counts()).reset_index()
temp_df.sort_values('loan_intent',inplace=True)
temp_df.index=range(len(temp_df))
temp_df2=temp_df.groupby('loan_intent').agg({'count':'sum'}).reset_index()
temp_df2.columns=['loan_intent','sum_count']
temp_df=temp_df.merge(temp_df2,on=['loan_intent'])
temp_df=temp_df[temp_df['loan_status']==1]
temp_df.index=range(len(temp_df))
temp_df['default_rate']=temp_df['count']/temp_df['sum_count']
temp_df.sort_values('default_rate',inplace=True)
temp_df.index=range(len(temp_df))
temp_df.drop(['loan_status','count','sum_count'],axis=1,inplace=True)
temp_df
# Out:
#          loan_intent  default_rate
# 0            VENTURE      0.148539
# 1          EDUCATION      0.172516
# 2           PERSONAL      0.198981
# 3    HOMEIMPROVEMENT      0.261547
# 4            MEDICAL      0.267627
# 5  DEBTCONSOLIDATION      0.286760

# %%
temp_df=pd.DataFrame(df[['loan_grade','loan_status']].value_counts()).reset_index()
temp_df.sort_values('loan_grade',inplace=True)
temp_df.index=range(len(temp_df))
temp_df2=temp_df.groupby('loan_grade').agg({'count':'sum'}).reset_index()
temp_df2.columns=['loan_grade','sum_count']
temp_df=temp_df.merge(temp_df2,on=['loan_grade'])
temp_df=temp_df[temp_df['loan_status']==1]
temp_df.index=range(len(temp_df))
temp_df['default_rate']=temp_df['count']/temp_df['sum_count']
temp_df.sort_values('default_rate',inplace=True)
temp_df.index=range(len(temp_df))
temp_df.drop(['loan_status','count','sum_count'],axis=1,inplace=True)
temp_df
# Out:
#   loan_grade  default_rate
# 0          A      0.099598
# 1          B      0.163185
# 2          C      0.207518
# 3          D      0.590608
# 4          E      0.644860
# 5          F      0.705394
# 6          G      0.984375

# %%
temp_df=pd.DataFrame(df[['person_home_ownership','loan_status']].value_counts()).reset_index()
temp_df.sort_values('person_home_ownership',inplace=True)
temp_df.index=range(len(temp_df))
temp_df2=temp_df.groupby('person_home_ownership').agg({'count':'sum'}).reset_index()
temp_df2.columns=['person_home_ownership','sum_count']
temp_df=temp_df.merge(temp_df2,on=['person_home_ownership'])
temp_df=temp_df[temp_df['loan_status']==1]
temp_df.index=range(len(temp_df))
temp_df['default_rate']=temp_df['count']/temp_df['sum_count']
temp_df.sort_values('default_rate',inplace=True)
temp_df.index=range(len(temp_df))
temp_df.drop(['loan_status','count','sum_count'],axis=1,inplace=True)
temp_df
# Out:
#   person_home_ownership  default_rate
# 0                   OWN      0.074912
# 1              MORTGAGE      0.126187
# 2                 OTHER      0.311321
# 3                  RENT      0.316095

# %%
temp_df=pd.DataFrame(df[['cb_person_default_on_file','loan_status']].value_counts()).reset_index()
temp_df.sort_values('cb_person_default_on_file',inplace=True)
temp_df.index=range(len(temp_df))
temp_df2=temp_df.groupby('cb_person_default_on_file').agg({'count':'sum'}).reset_index()
temp_df2.columns=['cb_person_default_on_file','sum_count']
temp_df=temp_df.merge(temp_df2,on=['cb_person_default_on_file'])
temp_df=temp_df[temp_df['loan_status']==1]
temp_df.index=range(len(temp_df))
temp_df['default_rate']=temp_df['count']/temp_df['sum_count']
temp_df.sort_values('default_rate',inplace=True)
temp_df.index=range(len(temp_df))
temp_df.drop(['loan_status','count','sum_count'],axis=1,inplace=True)
temp_df
# Out:
#   cb_person_default_on_file  default_rate
# 0                         N      0.184329
# 1                         Y      0.378709

# %%
df[num_features]
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 32576          57          53000                1.0       5800          13.16
# 32577          54         120000                4.0      17625           7.49
# 32578          65          76000                3.0      35000          10.99
# 32579          56         150000                5.0      15000          11.48
# 32580          66          42000                2.0       6475           9.99
#
#        loan_percent_income  cb_person_cred_hist_length
# 0                     0.59                           3
# 1                     0.10                           2
# 2                     0.57                           3
# 3                     0.53                           2
# 4                     0.55                           4
# ...                    ...                         ...
# 32576                 0.11                          30
# 32577                 0.15                          19
# 32578                 0.46                          28
# 32579                 0.10                          26
# 32580                 0.15                          30
#
# [32416 rows x 7 columns]

# %%
import seaborn as sns
sns.pairplot(df[num_features].dropna())

# %%
df['person_income'].hist(bins=100)
# Out:
# <Axes: >

# %%
df['person_income'].describe()
# Out:
# count    3.241600e+04
# mean     6.609164e+04
# std      6.201558e+04
# min      4.000000e+03
# 25%      3.854200e+04
# 50%      5.500000e+04
# 75%      7.921800e+04
# max      6.000000e+06
# Name: person_income, dtype: float64

# %%
df.loc[df['person_income']<500000,'person_income'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Identifying outliers and extreme values

# %%
df[num_features]
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 32576          57          53000                1.0       5800          13.16
# 32577          54         120000                4.0      17625           7.49
# 32578          65          76000                3.0      35000          10.99
# 32579          56         150000                5.0      15000          11.48
# 32580          66          42000                2.0       6475           9.99
#
#        loan_percent_income  cb_person_cred_hist_length
# 0                     0.59                           3
# 1                     0.10                           2
# 2                     0.57                           3
# 3                     0.53                           2
# 4                     0.55                           4
# ...                    ...                         ...
# 32576                 0.11                          30
# 32577                 0.15                          19
# 32578                 0.46                          28
# 32579                 0.10                          26
# 32580                 0.15                          30
#
# [32416 rows x 7 columns]

# %% [markdown]
# ## large person age

# %%
df['person_age'].hist()
# Out:
# <Axes: >

# %%
df[df['person_age']>80]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
# 32416          94          24000                  RENT                1.0
# 32506          84          94800              MORTGAGE                2.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate loan_status  \
# 81        VENTURE          C       4800          13.57           0
# 183     EDUCATION          B       6000          11.86           0
# 575     EDUCATION          B      20400          10.25           0
# 747       VENTURE          B      20000            NaN           0
# 32297    PERSONAL          C       5000          12.73           0
# 32416     MEDICAL          C       6500            NaN           0
# 32506    PERSONAL          A      10000           7.51           0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# 183                   0.03                         N
# 575                   0.25                         N
# 747                   0.26                         N
# 32297                 0.00                         N
# 32416                 0.27                         N
# 32506                 0.11                         N
#
#        cb_person_cred_hist_length
# 81                              3
# 183                             2
# 575                             3
# 747                             4
# 32297                          25
# 32416                          27
# 32506                          24

# %% [markdown]
# - suspricious observations are `[81,183,575,747,32297]`.

# %% [markdown]
# ## person income

# %%
df['person_income'].hist()
# Out:
# <Axes: >

# %%
df['person_income'].describe()
# Out:
# count    3.241600e+04
# mean     6.609164e+04
# std      6.201558e+04
# min      4.000000e+03
# 25%      3.854200e+04
# 50%      5.500000e+04
# 75%      7.921800e+04
# max      6.000000e+06
# Name: person_income, dtype: float64

# %%
df.loc[df['person_income']<320000,'person_income'].hist(bins=40)
# Out:
# <Axes: >

# %%
df[df['person_income']>500000]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 17833          32        1200000              MORTGAGE                1.0
# 17834          34         948000              MORTGAGE               18.0
# 17840          35         648000              MORTGAGE                6.0
# 17846          30         504000                  RENT                4.0
# 18635          31         636000                  RENT                2.0
# 18917          35         510000                  RENT                1.0
# 21462          33         612000                  RENT                3.0
# 21958          34         564000                  RENT                2.0
# 23429          31         552000                  RENT                0.0
# 23431          30         648000                  RENT                NaN
# 25714          32         703800                  RENT               14.0
# 27798          32         572400                  RENT               16.0
# 27877          30         522000              MORTGAGE               11.0
# 27881          28         604000              MORTGAGE               12.0
# 27882          31         741600              MORTGAGE                3.0
# 27883          32         750000              MORTGAGE                2.0
# 27884          35         762000                   OWN                8.0
# 28253          35         762000                   OWN                8.0
# 28633          33         612000                  RENT                3.0
# 29119          36        1200000                   OWN               16.0
# 29120          40        1200000              MORTGAGE                1.0
# 29121          50         900000              MORTGAGE               11.0
# 29122          36         900000              MORTGAGE                8.0
# 29126          39         708000              MORTGAGE               14.0
# 29127          44         584800              MORTGAGE                4.0
# 29128          36         700000              MORTGAGE               16.0
# 29129          40         540600              MORTGAGE                8.0
# 29345          42         889000                  RENT               13.0
# 29514          37         528000                  RENT                4.0
# 30049          42        2039784                  RENT                0.0
# 30536          37         780000                  RENT                9.0
# 31911          40         550000              MORTGAGE                4.0
# 31912          40         550000              MORTGAGE                5.0
# 31913          37         600000                   OWN               11.0
# 31915          42         600000                 OTHER                2.0
# 31916          43         780000              MORTGAGE                2.0
# 31918          37         800000              MORTGAGE               10.0
# 31919          36         828000              MORTGAGE                3.0
# 31921          37         900000              MORTGAGE                5.0
# 31922          47        1362000              MORTGAGE                9.0
# 31924          44        1440000              MORTGAGE                7.0
# 32037          36         828000              MORTGAGE                3.0
# 32070          37         780000                  RENT                9.0
# 32291          42         600000                 OTHER                2.0
# 32297         144        6000000              MORTGAGE               12.0
# 32298          58         900000                  RENT               18.0
# 32300          51         667680              MORTGAGE               19.0
# 32497          63        1782000                  RENT               13.0
# 32543          52         720000              MORTGAGE                1.0
# 32544          58         780000              MORTGAGE                7.0
# 32546          60        1900000              MORTGAGE                5.0
# 32551          58         780000              MORTGAGE                7.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate loan_status  \
# 17833            VENTURE          A      12000           7.51           0
# 17834           PERSONAL          B       2000           9.99           0
# 17840           PERSONAL          E      10000          17.19           1
# 17846  DEBTCONSOLIDATION          B       3000          11.36           0
# 18635  DEBTCONSOLIDATION          B      17500          11.48           0
# 18917           PERSONAL          C       1800          13.48           0
# 21462  DEBTCONSOLIDATION          C       5950          12.73           0
# 21958            MEDICAL          A       6000           7.14           0
# 23429           PERSONAL          A       8000           7.29           0
# 23431  DEBTCONSOLIDATION          C       8000          12.73           0
# 25714            MEDICAL          D      12000          15.33           1
# 27798            MEDICAL          B      16000           9.76           0
# 27877    HOMEIMPROVEMENT          A       2500           7.43           0
# 27881           PERSONAL          B      25000           9.01           1
# 27882            MEDICAL          B      12000          10.25           0
# 27883  DEBTCONSOLIDATION          B      30000           9.91           0
# 27884            MEDICAL          A      10000           8.94           0
# 28253            MEDICAL          A      10000           8.94           0
# 28633            MEDICAL          C       5950          12.73           0
# 29119            MEDICAL          A      10000           6.54           0
# 29120            MEDICAL          A      10000            NaN           0
# 29121  DEBTCONSOLIDATION          B      30000          12.69           0
# 29122           PERSONAL          B       6000            NaN           0
# 29126  DEBTCONSOLIDATION          B      25000          12.18           0
# 29127            MEDICAL          C      20000            NaN           1
# 29128            MEDICAL          C      25000          12.53           0
# 29129            MEDICAL          D      35000          15.99           1
# 29345          EDUCATION          A      20000            NaN           0
# 29514            VENTURE          D      15000            NaN           0
# 30049            VENTURE          C       8450          12.29           0
# 30536    HOMEIMPROVEMENT          B       7500          12.18           0
# 31911            VENTURE          B      18000          11.12           0
# 31912            MEDICAL          B       8000          10.75           0
# 31913    HOMEIMPROVEMENT          B      16000          10.25           0
# 31915          EDUCATION          D      25000          14.74           0
# 31916    HOMEIMPROVEMENT          A       1000           8.94           0
# 31918  DEBTCONSOLIDATION          B      15000          11.36           0
# 31919    HOMEIMPROVEMENT          B       4200            NaN           0
# 31921           PERSONAL          C      25000          12.87           0
# 31922            VENTURE          A       6600           7.74           0
# 31924  DEBTCONSOLIDATION          A       6400           7.40           0
# 32037            MEDICAL          B       4200            NaN           0
# 32070            VENTURE          B       7500          12.18           0
# 32291    HOMEIMPROVEMENT          D      25000          14.74           0
# 32297           PERSONAL          C       5000          12.73           0
# 32298  DEBTCONSOLIDATION          C      19600          13.98           0
# 32300           PERSONAL          C      10000          13.98           0
# 32497          EDUCATION          C      12025          14.27           0
# 32543           PERSONAL          A       7925           8.94           0
# 32544           PERSONAL          A       4500           6.91           0
# 32546           PERSONAL          A       1500            NaN           0
# 32551           PERSONAL          A       4500           6.91           0
#
#        loan_percent_income cb_person_default_on_file  \
# 17833                 0.01                         N
# 17834                 0.00                         N
# 17840                 0.02                         Y
# 17846                 0.01                         N
# 18635                 0.03                         N
# 18917                 0.00                         N
# 21462                 0.01                         Y
# 21958                 0.01                         N
# 23429                 0.01                         N
# 23431                 0.01                         Y
# 25714                 0.01                         Y
# 27798                 0.03                         N
# 27877                 0.00                         N
# 27881                 0.04                         N
# 27882                 0.02                         N
# 27883                 0.04                         N
# 27884                 0.01                         N
# 28253                 0.01                         N
# 28633                 0.01                         Y
# 29119                 0.01                         N
# 29120                 0.01                         N
# 29121                 0.03                         N
# 29122                 0.01                         N
# 29126                 0.04                         N
# 29127                 0.03                         Y
# 29128                 0.04                         Y
# 29129                 0.06                         Y
# 29345                 0.02                         N
# 29514                 0.03                         N
# 30049                 0.00                         Y
# 30536                 0.01                         N
# 31911                 0.03                         N
# 31912                 0.01                         N
# 31913                 0.03                         N
# 31915                 0.04                         N
# 31916                 0.00                         N
# 31918                 0.02                         N
# 31919                 0.01                         N
# 31921                 0.03                         Y
# 31922                 0.00                         N
# 31924                 0.00                         N
# 32037                 0.01                         N
# 32070                 0.01                         N
# 32291                 0.04                         Y
# 32297                 0.00                         N
# 32298                 0.02                         N
# 32300                 0.01                         Y
# 32497                 0.01                         N
# 32543                 0.01                         N
# 32544                 0.01                         N
# 32546                 0.00                         N
# 32551                 0.01                         N
#
#        cb_person_cred_hist_length
# 17833                           8
# 17834                           7
# 17840                           8
# 17846                           9
# 18635                          10
# 18917                           6
# 21462                           9
# 21958                           5
# 23429                          10
# 23431                          10
# 25714                           9
# 27798                           5
# 27877                           9
# 27881                           9
# 27882                           6
# 27883                           8
# 27884                          10
# 28253                           8
# 28633                          10
# 29119                          11
# 29120                          16
# 29121                          15
# 29122                          12
# 29126                          12
# 29127                          16
# 29128                          13
# 29129                          11
# 29345                          17
# 29514                          12
# 30049                          15
# 30536                          15
# 31911                          12
# 31912                          14
# 31913                          14
# 31915                          11
# 31916                          11
# 31918                          17
# 31919                          16
# 31921                          13
# 31922                          17
# 31924                          15
# 32037                          13
# 32070                          13
# 32291                          16
# 32297                          25
# 32298                          28
# 32300                          22
# 32497                          30
# 32543                          30
# 32544                          20
# 32546                          21
# 32551                          19

# %% [markdown]
# # Training and testing split

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(df,random_state=42,stratify=df['loan_status'],test_size=0.2)

# %% [markdown]
# # Handling Categorical data

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder().fit(train[cat_features])
X_train_cat=ohe.transform(train[cat_features]).toarray()
X_test_cat=ohe.transform(test[cat_features]).toarray()

# %% [markdown]
# # Handling numerical features

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer().fit(train[num_features])
X_train_num=pt.transform(train[num_features])
X_test_num=pt.transform(test[num_features])

# %%
X_train=np.concatenate((X_train_num,X_train_cat),axis=1)
X_test=np.concatenate((X_test_num,X_test_cat),axis=1)

# %%
X_test.shape,X_train.shape
# Out:
# ((6484, 26), (25932, 26))

# %% [markdown]
# # Target Engineering

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder().fit(train['loan_status'].astype('category'))
y_train=le.transform(train['loan_status'].astype('category'))
y_test=le.transform(test['loan_status'].astype('category'))

# %% [markdown]
# # Handling missing variables (Imputation)

# %%
from sklearn.impute import KNNImputer
knn_imp=KNNImputer().fit(X_train)
X_train=knn_imp.transform(X_train)
X_test=knn_imp.transform(X_test)

# %% [markdown]
# # Saving the dataset

# %% [markdown]
# # Bench mark

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier().fit(X_train,y_train)
pred=model.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score,confusion_matrix,accuracy_score,recall_score,roc_curve,f1_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.886335595311536

# %%
recall_score(y_test,pred)
# Out:
# 0.7729196050775741

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[4651,  415],
#        [ 322, 1096]], dtype=int64)

# %%
roc_auc_score(y_test,pred)
# Out:
# 0.8455004657839509

# %%
f1_score(y_test,pred)
# Out:
# 0.7483782861044724

# %%
model.predict(X_test)
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#define metrics
y_pred_proba = model.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
pd.Series(model.predict_proba(X_test)[:,0]).value_counts()
# Out:
# 1.0    4973
# 0.0    1511
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model2=RandomForestClassifier(n_estimators=4000).fit(X_train,y_train)
pred2=model2.predict(X_test)

# %%
accuracy_score(y_test,pred2)
# Out:
# 0.9353793954349168

# %%
roc_auc_score(y_test,pred2)
# Out:
# 0.8596201508215673

# %%
f1_score(y_test,pred2)
# Out:
# 0.8307070707070706

# %%
recall_score(y_test,pred2)
# Out:
# 0.7249647390691114

# %%
#define metrics
y_pred_proba2= model2.predict_proba(X_test)[::,1]
fpr2, tpr2, _ = roc_curve(y_test,  y_pred_proba2)

#create ROC curve
plt.plot(fpr2,tpr2)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Saving_processied dataset

# %%
pd.DataFrame(X_train).to_csv('C:\workspace\Credit-Risk-Modeling\dataset\kaggle_pd_estimation\X_train.csv')
pd.DataFrame(y_train.reshape((-1,1))).to_csv('C:\workspace\Credit-Risk-Modeling\dataset\kaggle_pd_estimation\y_train.csv')

pd.DataFrame(X_test).to_csv('C:\workspace\Credit-Risk-Modeling\dataset\kaggle_pd_estimation\X_test.csv')
pd.DataFrame(y_test.reshape((-1,1))).to_csv('C:\workspace\Credit-Risk-Modeling\dataset\kaggle_pd_estimation\y_test.csv')

# %%
pd.DataFrame(y_train.reshape((-1,1)))
# Out:
#        0
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
# ...   ..
# 25927  0
# 25928  0
# 25929  0
# 25930  0
# 25931  0
#
# [25932 rows x 1 columns]
